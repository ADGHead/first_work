# %% [markdown]
# #  <center><u>Hotel Bookings Report</u></center>

# %% [markdown]
# ### <u>Introduction:</u>
# The reason for this report is to test my ability in being able to analyse diverse data, apply inclusive analysis to the data given and gather the data and provide something meaningful with it. The task was given to me by my teacher, Mr. Godstime Edet. He provided the data set which I would be working on: <b>hotel_bookings.csv</b>.
# <p>The data set gives a basic description on the types of people that have made bookings in the various hotels for the duration of three years(2015-2017). There have been <u>119,390</u> people in that timespan, with some of them having missing data.</p>

# %% [markdown]
# I have extracted the people that had missing values in the data set by using the common occurences between them. I also filled in the null values in the data set by using the corresponding mean for numerical data and filled in my own values for the qualitative data.

# %% [markdown]
# The report basically talks about what I had observed in the data and the common occurences between the data in the data set with my conclusions about everything after analysing the data set inclusively.

# %% [markdown]
# ### <u>Data</u>

# %% [markdown]
# The data set contained 119,390 rows and 32 columns. The rows represents the number of people that we have data on while the columns represents the categories of data that has been collected on the people.e.g arrival date, arraival month, deposit type e.t.c.

# %% [markdown]
# ![hotelbookings.png](attachment:hotelbookings.png)

# %% [markdown]
# ### <u>Analysis</u>

# %% [markdown]
# - Firstly, I imported the numpy library from python and the saved it as np then I imported the pandas library from python and saved it as pd.
# - I imported the hotel bookings csv(comma seperated value) file using the function read_csv and assigned it to a variable named data.
# - I called the variable.
# - From my brief analysis, I was able to confirm that the data set had 119,390 rows and 32 columns respectively.
# - Using the isnull() function to obtain the columns that had missing values of data.
# I was able to obtain the following:
# 1. children: 4 missing values
# 2. country : 488 missing values
# 3. agent : 16,340 missing values
# 4. company : 112,593 missing values
# - Using the dtypes function to get the various data types that each column stored
# - Using the info() function to find out more information about the data set and the various data types. From my analysis, I observed that:
# 1.  The float64 data type was used in 4 columns
# 2.  The int64 data type was used in 16 columns
# 3.  The object data type was used in 12 columns

# %% [markdown]
# - Using the describe() function I was able to obtain the following information:
# 1. The average of people that canceled was 0.37.
# 2. The average lead time was 104.
# 3. Most people booked in 2016.
# 4. Most people arrived on the 27th week.
# 5. Most people arrived on the 15th day of any month.
# 6. The average of the amount of people that stayed on weekend nights was 0.93.
# 7. The average of the amount of people that stayed on week nights was 2.
# 8. There was atleast one adult among the people that made bookings.
# 9. The average amount of children that was among the people that booked was 0.1.
# 10. The average amount of babies that was among the people that booked was 0.07.
# 11. The average amount of repeated guests was 0.08.
# 12. The average amount of previous bookings not canceled was 0.13.
# 13. The average amount of booking changes was 0.22.
# 14. From the values given(103,050), the average amount of agents was 86.
# 15. From the values given(6797), The average amount of companies was 189.
# 16. The average amount of days spent on the waiting list was 2.
# 17. The avergae adr(average daily rate) was 101.
# 18. The average amount of required parking spaces was 0.06.
# 19. The average amount of total special requests was 0.5.
# 20. The hotel column had 2 unique values(City hotel and Resort hotel) with people booking at the city hotel more(79,330).
# 21. People booked in every month of the year but august was the most(13,877).
# 22. Meal had 5 unique values with BB occuring the most (92,310).
# 23. Country had 177 unique values with PRT(Portugal) ocurring the most(48,590).
# 24. Market segment had 8 unique values with online TA appearing the most(56,477).
# 25. Reserved room type had 10 unique values with A occuring the most (85,994).
# 26. Assigned room type had 12 unique values with A appearing the most(74,053).
# 27. Deposit type had 3 unique values(No Deposit, Refundable, Non Refund) with No deposit appearing the most(104,641).
# 28. Customer type had 4 unique values(Transient, contract, Transient-Party, Group) with Transient appearing the most(89,613).
# 29. Reservation status had 3 unique values(Check-out, cancelled, No show) with Check-out appearing the most(75,166).
# 30. Reservation status date had 926 unique values with 2015-10-21(21<sup>st</sup> october 2015) occuring the most(1461).
# 31. The average amount of previous cancellations was 0.08.
# 32. The distribution channel had 5 unique values with TA/TO occuring the most(97,870).

# %% [markdown]
# - Using a function, I was able to extract the People that had missing values by using their similarities. From my analysis, I was able to obtain the following sets of information:
# 1. There were 10,090 people that had missing values.
# 2. Most of them booked in october(1,060).
# 3. Most of them had the BB meal(8,492).
# 4. The country column only had 9,602 people and 87 unique values as opposed to the 177 unique values and 10,090 people with PRT(Portugal) occuring the most(6,576).
# 5. Market segment only had 7 unique values out of 8 with direct occuring the most(5,848). Aviation was the missing value.
# 6. Distribution channel had 5 unique values with Direct occuring the most(6,873).
# 7. Reserved room type had 10 unique values with A occuring the most(7,055).
# 8. Assigned room type had 12 unique values with A occuring the most(5,443).
# 9. Deposit type had 3 unique values with No deposit occuring the most(8,508).
# 10. Customer type had 4 unique values with Transient occuring the most(7,923).
# 11. Reservation status date had 3 unique values as Check-out occured the most(7,178).
# 12. Reservation status date had 815 unique values as opposed to the 926 values with (25<sup>th</sup> November 2016 occuring the most)(220).
# 13. The average amount of them that cancelled was 0.2.
# 14. The average lead time was 59.
# 15. Most of them booked in 2016.
# 16. Most of them arrived on the 26th week.
# 17. Most of them arrived on the 15th day of any month.
# 18. The average of the amount of them that stayed on weekend nights was 0.7.
# 19. The average of the amount of them that stayed on week nights was 2.
# 20. There was atleast one adult among them that made bookings.
# 21. The average amount of children from the values given(10,086) that was among the people that booked was 0.08.
# 22. The average amount of babies that was among them that booked was 0.13.
# 23. The average amount of repeated guests was 0.07.
# 24. The average amount of previous bookings not canceled was 0.13.
# 25. The average amount of booking changes was 0.2.
# 26. From the values given(156), the average amount of agents was 184.
# 27. From the values given(174), The average amount of companies was 175.
# 28. The average amount of days spent on the waiting list was 0.55.
# 29. The average adr(average daily rate) was 94.
# 30. The average amount of required parking spaces was 0.12.
# 31. The average amount of total special requests was 0.42.
# 32. The average amount of previous cancellations was 0.13

# %% [markdown]
# - Using a function, I then filled in the values for children, agent, company using their mean values.
# - I then filled the values for country that were null by assigning them to "PRT".

# %% [markdown]
# ### <u>Conclusion</u>

# %% [markdown]
# Based on the information gotten from my analysis of the data set. I was able to arrive at a conclusion, which was:
# The hotels were relatively famous, busy most of the time and had a good reputation.The People that booked comprised of mostly adults with few children and even fewer babies. The people were mostly foreigners and came either on a business trip or for the holidays. There was a high demand of space which lead to people making reservations a year ahead of time. The missing values in agent and company were due to the fact that the people did not need any agent or company to help them make bookings.

# %% [markdown]
# ### <u>Appendix</u>

# %% [markdown]
# <u>Description of the data</u>

# %% [markdown]
# ![Screenshot%202023-07-27%20223711.png](attachment:Screenshot%202023-07-27%20223711.png)

# %% [markdown]
# ![Screenshot%202023-07-27%20223834.png](attachment:Screenshot%202023-07-27%20223834.png)

# %% [markdown]
# <u>Codes used in the analysis of the data</u>

# %% [markdown]
# 1. To import the libraries:
# - import numpy as np
# - import pandas as pd

# %% [markdown]
# 2. To import the file and save it as a variable:
# - data = pd.read_csv("hotel_bookings.csv")

# %% [markdown]
# 3. To find the null values on the data set:
# - data.isnull().sum()

# %% [markdown]
# 4. To find the data types in the data set:
# - data.dtypes

# %% [markdown]
# 5. To find the info of the data set:
# - data.info()

# %% [markdown]
# 6. To get the description of the data set:
# - data.describe()
# - data.describe(include="O")

# %% [markdown]
# 7. To seperate the null values from the data using their similarities and store them in a particular variable which can be called on:
# - data2 = data.loc[(data["agent"].isnull()) & (data["company"].isnull()) | (data["country"].isnull()) | (data["children"].isnull())]

# %% [markdown]
# 8. To fill in the null values using their corresponding mean(only works for numerical data):
# - data.loc[(data["children"].isnull() == True,"children")] = data["children"].mean()
# - data.loc[(data["agent"].isnull() == True,"agent")] = data["agent"].mean()
# - data.loc[(data["company"].isnull() == True,"company")] = data["company"].mean()

# %% [markdown]
# 9. To fill in the null values in qualitative data:
# - data.loc[(data["country"].isnull() == True,"country")] = "PRT"
